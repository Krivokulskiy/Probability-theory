# %% [markdown]
# ДЗ сдавать ссылкой на github
# 1) Из колоды в 52 карты извлекаются случайным образом 4 карты. a) Найти вероятность того, что все карты – крести. б) Найти вероятность, что среди 4-х карт окажется хотя бы один туз.

# %% [markdown]
# Рассуждения: В колоде 52 карты, исходим из того что масти распределены одинаково, таким образом получаем, что количество карт для каждой масти равно 52/4=13. То есть 13 карт из 52 имеют масть крести. Сочетание 4 из 13 есть число благоприятствующих искомому событий для карт масти крести. Сочетания 4 из 52 (общему числу карт) общее число всех возможных комбинаций карт.

# %%
from math import factorial
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))
C1=combinations(13,4)
print('количество сочетаний 4 карт мас ти крести: ', C1)
C2=combinations(52,4)
print ('количесто всех сочитаний 4 карт из 52 карт:', C2)
print ('Искомая вероятность выпадения 4 карт масти крести: ', C1/C2, 'процентов')
# Out:
# количество сочетаний 4 карт мас ти крести:  715
# количесто всех сочитаний 4 карт из 52 карт: 270725
# Искомая вероятность выпадения 4 карт масти крести:  0.0026410564225690276 процентов

# %%
C21=combinations(48,4)
C22=combinations(52,4)
C23=(C22-C21)/C22
print('Вероятность того, что при выборе 4 карт как минимум 1 будет тузом: ',C23*100, '%')
# Out:
# Вероятность того, что при выборе 4 карт как минимум 1 будет тузом:  28.126327454058547 %

# %% [markdown]
# 2) На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %%
AllComb=combinations(10,3)
print('Общее количество возможных комбинаций для 10 чисел для набора по 3 числа: ', AllComb)
C=1/AllComb*100
print ('Вероятность набрать код с одной попвтки: ', C, '%')
# Out:
# Общее количество возможных комбинаций для 10 чисел для набора по 3 числа:  120
# Вероятность набрать код с одной попвтки:  0.8333333333333334 %

# %% [markdown]
# 3) В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?

# %%
C31=combinations(9,3)
C32=combinations(15,3)
print ('Вероятность выбора 3 окрашенных деталей за 1 озвлечение: ',C31/C32*100, '%')
# Out:
# Вероятность выбора 3 окрашенных деталей за 1 озвлечение:  18.461538461538463 %

# %% [markdown]
# 4) В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %%
print('Вероятность приобретения 2 выйгрышных билетов: ',1/100*2/99)
# Out:
# Вероятность приобретения 2 выйгрышных билетов:  0.00020202020202020202
